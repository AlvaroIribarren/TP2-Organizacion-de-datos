# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
sns.set_style('darkgrid')
df= pd.read_csv("/kaggle/input/entrenamiento/train.csv")
nuevo = df[['habitaciones','gimnasio','garages','precio']]

df = df.replace(np.nan,"0")
habitaciones = df['habitaciones'].values
gimnasio = df['gimnasio'].values
garages = df['garages'].values
precio = df['precio'].values
metroscubiertos = df['metroscubiertos'].values
metrostotales = df['metrostotales'].values
piscina = df['piscina'].values
usosmlt = df['usosmultiples'].values
antiguedad = df['antiguedad'].values
banos = df['banos'].values

escuelascercanas = df['escuelascercanas'].values
centroscomercialescercanos = df['centroscomercialescercanos'].values

X=np.array([metroscubiertos]).T
Y=np.array(precio)

reg= LinearRegression()
reg=reg.fit(X,Y)

Y_pred=reg.predict(X)

error = np.sqrt(mean_squared_error(Y,Y_pred))
r2 = reg.score(X,Y)

print("el error es de: ",error)


print("Precision del modelo: ",reg.score(X,Y))

#plt.scatter(X, Y, color = 'red')
#plt.plot(X, Y_pred, color = 'blue')
# Out:
# /kaggle/input/Inmuebles24/test.csv
# /kaggle/input/entrenamiento/train.csv
# el error es de:  1874069.594540235
# Precision del modelo:  0.2420055651206251

# %%
XTT=np.array([metroscubiertos,habitaciones,usosmlt,banos]).T
YTT=np.array(precio)
#plt.rcParams['figure.figsize'] = [13, 19]
#plt.scatter(XTT,YTT)
reg=PolynomialFeatures(degree=5)
XXT = reg.fit_transform(XTT)
pr = LinearRegression()
pr.fit(XXT,YTT)
y_test = pr.predict(XXT)
error = np.sqrt(mean_squared_error(YTT,y_test))



print("error del precio: ",error)
print("Precision del modelo: ",pr.score(XXT,YTT))
# Out:
# error del precio:  1599978.1112748426
# Precision del modelo:  0.44751222794313694

# %%
from sklearn.linear_model import LogisticRegression
XTT=np.array([metroscubiertos]).T
YTT=np.array(precio)
#plt.rcParams['figure.figsize'] = [13, 19]
#plt.scatter(XTT,YTT)
pr = LogisticRegression(penalty='l2')
pr.fit(XXT,YTT)
y_test = pr.predict(XXT)
error = np.sqrt(mean_squared_error(YTT,y_test))



print("error del precio: ",error)
print("Precision del modelo: ",pr.score(XXT,YTT))
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
